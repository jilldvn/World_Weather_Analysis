# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description= city_weather["weather"][0]["description"]
       
        # Append the city information into the city_data list
        # YOUR CODE HERE
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description})
        
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | dover
# Processing Record 5 of Set 1 | touros
# Processing Record 6 of Set 1 | chitral
# Processing Record 7 of Set 1 | kurumkan
# Processing Record 8 of Set 1 | barra do garcas
# Processing Record 9 of Set 1 | kulmbach
# Processing Record 10 of Set 1 | kamariotissa
# Processing Record 11 of Set 1 | tiksi
# Processing Record 12 of Set 1 | kualakapuas
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | longyearbyen
# Processing Record 15 of Set 1 | victoria
# Processing Record 16 of Set 1 | east london
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | faanui
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | vanderhoof
# Processing Record 22 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 1 | saint-michel-des-saints
# Processing Record 24 of Set 1 | vardo
# Processing Record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 1 | fortuna
# Processing Record 27 of Set 1 | quatre cocos
# Processing Record 28 of Set 1 | jabiru
# City not found. Skipping...
# Processing Record 29 of Set 1 | hasaki
# Processing Record 30 of Set 1 | booue
# Processing Record 31 of Set 1 | saskylakh
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | kuytun
# Processing Record 35 of Set 1 | aleksandrovskoye
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | katsuura
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | lebu
# Processing Record 43 of Set 1 | ancud
# Processing Record 44 of Set 1 | kodiak
# Processing Record 45 of Set 1 | narsaq
# Processing Record 46 of Set 1 | clyde river
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | maldonado
# Processing Record 49 of Set 1 | iki-burul
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | taldan
# Processing Record 2 of Set 2 | bambous virieux
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | flinders
# Processing Record 6 of Set 2 | jatai
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | margate
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | mount isa
# Processing Record 13 of Set 2 | fort oglethorpe
# Processing Record 14 of Set 2 | port-gentil
# Processing Record 15 of Set 2 | saint-philippe
# Processing Record 16 of Set 2 | alta floresta
# Processing Record 17 of Set 2 | punta arenas
# Processing Record 18 of Set 2 | labrea
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | kenora
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 2 | torbay
# Processing Record 25 of Set 2 | vao
# Processing Record 26 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 2 | ciudad bolivar
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | yar-sale
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | of
# City not found. Skipping...
# Processing Record 33 of Set 2 | palana
# Processing Record 34 of Set 2 | polyarnyy
# Processing Record 35 of Set 2 | thompson
# Processing Record 36 of Set 2 | bathsheba
# Processing Record 37 of Set 2 | boa viagem
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | demyansk
# Processing Record 40 of Set 2 | muroto
# Processing Record 41 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 2 | pauini
# Processing Record 43 of Set 2 | dipkarpaz
# City not found. Skipping...
# Processing Record 44 of Set 2 | vila franca do campo
# Processing Record 45 of Set 2 | beyneu
# Processing Record 46 of Set 2 | taoudenni
# Processing Record 47 of Set 2 | amarante do maranhao
# Processing Record 48 of Set 2 | gat
# Processing Record 49 of Set 2 | butaritari
# Processing Record 50 of Set 2 | umkomaas
# Processing Record 1 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 3 | barrow
# Processing Record 3 of Set 3 | litoral del san juan
# City not found. Skipping...
# Processing Record 4 of Set 3 | burnie
# Processing Record 5 of Set 3 | puerto ayora
# Processing Record 6 of Set 3 | teguldet
# Processing Record 7 of Set 3 | arraial do cabo
# Processing Record 8 of Set 3 | georgetown
# Processing Record 9 of Set 3 | santa rosa
# Processing Record 10 of Set 3 | mingaora
# Processing Record 11 of Set 3 | mahajanga
# Processing Record 12 of Set 3 | nouadhibou
# Processing Record 13 of Set 3 | leh
# Processing Record 14 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 3 | salihorsk
# Processing Record 16 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 3 | port lincoln
# Processing Record 18 of Set 3 | hami
# Processing Record 19 of Set 3 | pangnirtung
# Processing Record 20 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 3 | maragogi
# Processing Record 22 of Set 3 | shemysheyka
# Processing Record 23 of Set 3 | mahaicony
# City not found. Skipping...
# Processing Record 24 of Set 3 | lompoc
# Processing Record 25 of Set 3 | buzuluk
# Processing Record 26 of Set 3 | liku
# Processing Record 27 of Set 3 | constitucion
# Processing Record 28 of Set 3 | severo-kurilsk
# Processing Record 29 of Set 3 | mar del plata
# Processing Record 30 of Set 3 | hilo
# Processing Record 31 of Set 3 | sulina
# Processing Record 32 of Set 3 | kruisfontein
# Processing Record 33 of Set 3 | guerrero negro
# Processing Record 34 of Set 3 | klaksvik
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | provideniya
# Processing Record 37 of Set 3 | olafsvik
# Processing Record 38 of Set 3 | amga
# Processing Record 39 of Set 3 | zhigansk
# Processing Record 40 of Set 3 | salalah
# Processing Record 41 of Set 3 | strai
# Processing Record 42 of Set 3 | antalaha
# Processing Record 43 of Set 3 | odweyne
# Processing Record 44 of Set 3 | los llanos de aridane
# Processing Record 45 of Set 3 | san cristobal
# Processing Record 46 of Set 3 | mataura
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | kalemie
# Processing Record 49 of Set 3 | thaba nchu
# Processing Record 50 of Set 3 | nabire
# Processing Record 1 of Set 4 | ukiah
# Processing Record 2 of Set 4 | remanso
# Processing Record 3 of Set 4 | bardiyah
# Processing Record 4 of Set 4 | norman wells
# Processing Record 5 of Set 4 | lujan
# Processing Record 6 of Set 4 | lesozavodsk
# Processing Record 7 of Set 4 | sladkovo
# Processing Record 8 of Set 4 | lovec
# City not found. Skipping...
# Processing Record 9 of Set 4 | saint-pierre
# Processing Record 10 of Set 4 | tuktoyaktuk
# Processing Record 11 of Set 4 | aklavik
# Processing Record 12 of Set 4 | fomboni
# Processing Record 13 of Set 4 | naze
# Processing Record 14 of Set 4 | havoysund
# Processing Record 15 of Set 4 | pathein
# Processing Record 16 of Set 4 | ulundurpettai
# City not found. Skipping...
# Processing Record 17 of Set 4 | ambon
# Processing Record 18 of Set 4 | lazaro cardenas
# Processing Record 19 of Set 4 | vestmannaeyjar
# Processing Record 20 of Set 4 | farmington
# Processing Record 21 of Set 4 | surt
# Processing Record 22 of Set 4 | bethanien
# Processing Record 23 of Set 4 | abonnema
# Processing Record 24 of Set 4 | new norfolk
# Processing Record 25 of Set 4 | hofn
# Processing Record 26 of Set 4 | dunedin
# Processing Record 27 of Set 4 | aginskoye
# Processing Record 28 of Set 4 | hamilton
# Processing Record 29 of Set 4 | suez
# Processing Record 30 of Set 4 | noumea
# Processing Record 31 of Set 4 | grand forks
# Processing Record 32 of Set 4 | kirakira
# Processing Record 33 of Set 4 | byron bay
# Processing Record 34 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 4 | cabo san lucas
# Processing Record 36 of Set 4 | kieta
# Processing Record 37 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 38 of Set 4 | dubbo
# Processing Record 39 of Set 4 | pampa
# Processing Record 40 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 4 | lorengau
# Processing Record 42 of Set 4 | montepuez
# Processing Record 43 of Set 4 | markala
# Processing Record 44 of Set 4 | vestmanna
# Processing Record 45 of Set 4 | comodoro rivadavia
# Processing Record 46 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 4 | vallenar
# Processing Record 48 of Set 4 | namatanai
# Processing Record 49 of Set 4 | lake city
# Processing Record 50 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 1 of Set 5 | washington
# Processing Record 2 of Set 5 | inta
# Processing Record 3 of Set 5 | bandarbeyla
# Processing Record 4 of Set 5 | saint george
# Processing Record 5 of Set 5 | bilma
# Processing Record 6 of Set 5 | khatanga
# Processing Record 7 of Set 5 | manzil jamil
# City not found. Skipping...
# Processing Record 8 of Set 5 | kintinku
# Processing Record 9 of Set 5 | necochea
# Processing Record 10 of Set 5 | sitka
# Processing Record 11 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 5 | hualmay
# Processing Record 13 of Set 5 | hachinohe
# Processing Record 14 of Set 5 | cabedelo
# Processing Record 15 of Set 5 | waipawa
# Processing Record 16 of Set 5 | mount gambier
# Processing Record 17 of Set 5 | saint-joseph
# Processing Record 18 of Set 5 | maneadero
# Processing Record 19 of Set 5 | oistins
# Processing Record 20 of Set 5 | yamethin
# Processing Record 21 of Set 5 | imeni babushkina
# Processing Record 22 of Set 5 | emba
# Processing Record 23 of Set 5 | red bluff
# Processing Record 24 of Set 5 | cambrils
# Processing Record 25 of Set 5 | stromness
# Processing Record 26 of Set 5 | flin flon
# Processing Record 27 of Set 5 | pisco
# Processing Record 28 of Set 5 | porto novo
# Processing Record 29 of Set 5 | choucheng
# City not found. Skipping...
# Processing Record 30 of Set 5 | ardalstangen
# Processing Record 31 of Set 5 | diffa
# Processing Record 32 of Set 5 | andra
# Processing Record 33 of Set 5 | borazjan
# Processing Record 34 of Set 5 | bilibino
# Processing Record 35 of Set 5 | el faiyum
# City not found. Skipping...
# Processing Record 36 of Set 5 | paamiut
# Processing Record 37 of Set 5 | fort morgan
# Processing Record 38 of Set 5 | valparaiso
# Processing Record 39 of Set 5 | nedjo
# Processing Record 40 of Set 5 | pacific grove
# Processing Record 41 of Set 5 | rocha
# Processing Record 42 of Set 5 | ponta do sol
# Processing Record 43 of Set 5 | marsh harbour
# Processing Record 44 of Set 5 | brownsville
# Processing Record 45 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 5 | kodinsk
# Processing Record 47 of Set 5 | bonfim
# Processing Record 48 of Set 5 | dingle
# Processing Record 49 of Set 5 | cidreira
# Processing Record 50 of Set 5 | coquimbo
# Processing Record 1 of Set 6 | blairmore
# Processing Record 2 of Set 6 | chokurdakh
# Processing Record 3 of Set 6 | balabac
# Processing Record 4 of Set 6 | haines junction
# Processing Record 5 of Set 6 | henties bay
# Processing Record 6 of Set 6 | zalantun
# Processing Record 7 of Set 6 | calama
# Processing Record 8 of Set 6 | sistranda
# Processing Record 9 of Set 6 | lasa
# Processing Record 10 of Set 6 | oshakati
# Processing Record 11 of Set 6 | springbok
# Processing Record 12 of Set 6 | vila velha
# Processing Record 13 of Set 6 | mumford
# Processing Record 14 of Set 6 | estelle
# Processing Record 15 of Set 6 | kulhudhuffushi
# Processing Record 16 of Set 6 | nikolskoye
# Processing Record 17 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 18 of Set 6 | yima
# Processing Record 19 of Set 6 | beringovskiy
# Processing Record 20 of Set 6 | bemidji
# Processing Record 21 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 6 | hervey bay
# Processing Record 23 of Set 6 | broken hill
# Processing Record 24 of Set 6 | bol
# Processing Record 25 of Set 6 | amnat charoen
# Processing Record 26 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 6 | ambilobe
# Processing Record 28 of Set 6 | hannibal
# Processing Record 29 of Set 6 | wanning
# Processing Record 30 of Set 6 | pochutla
# Processing Record 31 of Set 6 | tuatapere
# Processing Record 32 of Set 6 | ilebo
# Processing Record 33 of Set 6 | qaqortoq
# Processing Record 34 of Set 6 | adrar
# Processing Record 35 of Set 6 | raudeberg
# Processing Record 36 of Set 6 | goderich
# Processing Record 37 of Set 6 | sorland
# Processing Record 38 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 6 | sinnamary
# Processing Record 40 of Set 6 | newport
# Processing Record 41 of Set 6 | nanortalik
# Processing Record 42 of Set 6 | bushenyi
# Processing Record 43 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 44 of Set 6 | bolonchen
# City not found. Skipping...
# Processing Record 45 of Set 6 | kazanskaya
# Processing Record 46 of Set 6 | port blair
# Processing Record 47 of Set 6 | isangel
# Processing Record 48 of Set 6 | merauke
# Processing Record 49 of Set 6 | carauari
# Processing Record 50 of Set 6 | novyy urengoy
# Processing Record 1 of Set 7 | pierre
# Processing Record 2 of Set 7 | ahipara
# Processing Record 3 of Set 7 | broome
# Processing Record 4 of Set 7 | saint anthony
# Processing Record 5 of Set 7 | cherskiy
# Processing Record 6 of Set 7 | jinji
# Processing Record 7 of Set 7 | matara
# Processing Record 8 of Set 7 | melendugno
# Processing Record 9 of Set 7 | shelburne
# Processing Record 10 of Set 7 | riyadh
# Processing Record 11 of Set 7 | nevesinje
# Processing Record 12 of Set 7 | namibe
# Processing Record 13 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 7 | kutum
# Processing Record 15 of Set 7 | port hedland
# Processing Record 16 of Set 7 | anadyr
# Processing Record 17 of Set 7 | panaba
# Processing Record 18 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 7 | kavaratti
# Processing Record 20 of Set 7 | hirara
# Processing Record 21 of Set 7 | la roche-sur-yon
# Processing Record 22 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 7 | veracruz
# Processing Record 24 of Set 7 | souillac
# Processing Record 25 of Set 7 | praia da vitoria
# Processing Record 26 of Set 7 | san quintin
# Processing Record 27 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 7 | durham
# Processing Record 29 of Set 7 | paracuru
# Processing Record 30 of Set 7 | ola
# Processing Record 31 of Set 7 | te anau
# Processing Record 32 of Set 7 | talnakh
# Processing Record 33 of Set 7 | cintalapa
# Processing Record 34 of Set 7 | ponta delgada
# Processing Record 35 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 36 of Set 7 | san jose
# Processing Record 37 of Set 7 | nizhniy kuranakh
# Processing Record 38 of Set 7 | bud
# Processing Record 39 of Set 7 | san francisco
# Processing Record 40 of Set 7 | khani
# Processing Record 41 of Set 7 | mombetsu
# Processing Record 42 of Set 7 | dalby
# Processing Record 43 of Set 7 | mecca
# Processing Record 44 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 7 | bereda
# Processing Record 46 of Set 7 | bengkulu
# Processing Record 47 of Set 7 | hai duong
# Processing Record 48 of Set 7 | iquitos
# Processing Record 49 of Set 7 | kuryk
# Processing Record 50 of Set 7 | aykhal
# Processing Record 1 of Set 8 | iqaluit
# Processing Record 2 of Set 8 | sioux lookout
# Processing Record 3 of Set 8 | severomuysk
# Processing Record 4 of Set 8 | pindiga
# Processing Record 5 of Set 8 | monte alegre
# Processing Record 6 of Set 8 | gatton
# Processing Record 7 of Set 8 | peniche
# Processing Record 8 of Set 8 | esperance
# Processing Record 9 of Set 8 | antofagasta
# Processing Record 10 of Set 8 | tecoanapa
# Processing Record 11 of Set 8 | maniitsoq
# Processing Record 12 of Set 8 | hurricane
# Processing Record 13 of Set 8 | gwadar
# Processing Record 14 of Set 8 | ye
# City not found. Skipping...
# Processing Record 15 of Set 8 | visinesti
# Processing Record 16 of Set 8 | airai
# Processing Record 17 of Set 8 | orange
# Processing Record 18 of Set 8 | camana
# Processing Record 19 of Set 8 | kushima
# Processing Record 20 of Set 8 | breves
# Processing Record 21 of Set 8 | ofunato
# Processing Record 22 of Set 8 | maceio
# Processing Record 23 of Set 8 | rudnogorsk
# Processing Record 24 of Set 8 | ebolowa
# Processing Record 25 of Set 8 | bhainsdehi
# Processing Record 26 of Set 8 | ukmerge
# Processing Record 27 of Set 8 | bredy
# Processing Record 28 of Set 8 | tullahoma
# Processing Record 29 of Set 8 | portland
# Processing Record 30 of Set 8 | grand-lahou
# Processing Record 31 of Set 8 | eyl
# Processing Record 32 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 8 | butembo
# Processing Record 34 of Set 8 | sri aman
# Processing Record 35 of Set 8 | luderitz
# Processing Record 36 of Set 8 | mikuni
# Processing Record 37 of Set 8 | bethel
# Processing Record 38 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 39 of Set 8 | barkhan
# Processing Record 40 of Set 8 | berlevag
# Processing Record 41 of Set 8 | ilulissat
# Processing Record 42 of Set 8 | urumqi
# Processing Record 43 of Set 8 | havre
# Processing Record 44 of Set 8 | bubaque
# Processing Record 45 of Set 8 | lagos
# Processing Record 46 of Set 8 | rapla
# Processing Record 47 of Set 8 | gazanjyk
# Processing Record 48 of Set 8 | salinopolis
# Processing Record 49 of Set 8 | nishihara
# Processing Record 50 of Set 8 | muros
# Processing Record 1 of Set 9 | singaraja
# Processing Record 2 of Set 9 | saumur
# Processing Record 3 of Set 9 | cabo rojo
# Processing Record 4 of Set 9 | ust-maya
# Processing Record 5 of Set 9 | mezen
# Processing Record 6 of Set 9 | la sarre
# Processing Record 7 of Set 9 | nemuro
# Processing Record 8 of Set 9 | ucluelet
# Processing Record 9 of Set 9 | pandan
# Processing Record 10 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 9 | boende
# Processing Record 12 of Set 9 | domoni
# Processing Record 13 of Set 9 | jaragua
# Processing Record 14 of Set 9 | amurzet
# Processing Record 15 of Set 9 | kadoma
# Processing Record 16 of Set 9 | morros
# Processing Record 17 of Set 9 | salon-de-provence
# Processing Record 18 of Set 9 | yulara
# Processing Record 19 of Set 9 | north myrtle beach
# Processing Record 20 of Set 9 | opuwo
# Processing Record 21 of Set 9 | linxia
# Processing Record 22 of Set 9 | jurm
# Processing Record 23 of Set 9 | hovd
# Processing Record 24 of Set 9 | malanje
# Processing Record 25 of Set 9 | ternate
# Processing Record 26 of Set 9 | anuradhapura
# Processing Record 27 of Set 9 | calabozo
# Processing Record 28 of Set 9 | wasilla
# Processing Record 29 of Set 9 | serravalle pistoiese
# Processing Record 30 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 31 of Set 9 | phan thiet
# Processing Record 32 of Set 9 | alice springs
# Processing Record 33 of Set 9 | barcelos
# Processing Record 34 of Set 9 | baltasi
# Processing Record 35 of Set 9 | killybegs
# Processing Record 36 of Set 9 | haljala
# Processing Record 37 of Set 9 | coahuayana
# Processing Record 38 of Set 9 | siderno
# Processing Record 39 of Set 9 | lata
# Processing Record 40 of Set 9 | imbituba
# Processing Record 41 of Set 9 | sur
# Processing Record 42 of Set 9 | dudinka
# Processing Record 43 of Set 9 | golkoy
# Processing Record 44 of Set 9 | uray
# Processing Record 45 of Set 9 | tera
# Processing Record 46 of Set 9 | turayf
# Processing Record 47 of Set 9 | iralaya
# Processing Record 48 of Set 9 | miraflores
# Processing Record 49 of Set 9 | atar
# Processing Record 50 of Set 9 | shangqiu
# Processing Record 1 of Set 10 | mao
# Processing Record 2 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 10 | aketi
# Processing Record 4 of Set 10 | giyani
# Processing Record 5 of Set 10 | imisli
# City not found. Skipping...
# Processing Record 6 of Set 10 | alihe
# Processing Record 7 of Set 10 | awbari
# Processing Record 8 of Set 10 | bundaberg
# Processing Record 9 of Set 10 | kahului
# Processing Record 10 of Set 10 | codrington
# Processing Record 11 of Set 10 | abu samrah
# Processing Record 12 of Set 10 | lagoa
# Processing Record 13 of Set 10 | russell
# Processing Record 14 of Set 10 | monrovia
# Processing Record 15 of Set 10 | nueva guinea
# Processing Record 16 of Set 10 | san patricio
# Processing Record 17 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 10 | vanimo
# Processing Record 19 of Set 10 | moose factory
# Processing Record 20 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 10 | rawson
# Processing Record 22 of Set 10 | balashov
# Processing Record 23 of Set 10 | thunder bay
# Processing Record 24 of Set 10 | marmaris
# Processing Record 25 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 26 of Set 10 | teguise
# Processing Record 27 of Set 10 | aksarka
# Processing Record 28 of Set 10 | lagunas
# Processing Record 29 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 30 of Set 10 | husavik
# Processing Record 31 of Set 10 | kavieng
# Processing Record 32 of Set 10 | ustka
# Processing Record 33 of Set 10 | bonthe
# Processing Record 34 of Set 10 | tahe
# Processing Record 35 of Set 10 | pitimbu
# Processing Record 36 of Set 10 | cozumel
# Processing Record 37 of Set 10 | kaitangata
# Processing Record 38 of Set 10 | kungurtug
# Processing Record 39 of Set 10 | belyy yar
# Processing Record 40 of Set 10 | chernyshevskiy
# Processing Record 41 of Set 10 | littlehampton
# Processing Record 42 of Set 10 | boa vista
# Processing Record 43 of Set 10 | kuching
# Processing Record 44 of Set 10 | dongying
# Processing Record 45 of Set 10 | agen
# Processing Record 46 of Set 10 | saint-augustin
# Processing Record 47 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 10 | makung
# City not found. Skipping...
# Processing Record 49 of Set 10 | caravelas
# Processing Record 50 of Set 10 | nhulunbuy
# Processing Record 1 of Set 11 | praia
# Processing Record 2 of Set 11 | sao filipe
# Processing Record 3 of Set 11 | santa fe
# Processing Record 4 of Set 11 | biak
# Processing Record 5 of Set 11 | wau
# Processing Record 6 of Set 11 | keti bandar
# Processing Record 7 of Set 11 | yerbogachen
# Processing Record 8 of Set 11 | padang
# Processing Record 9 of Set 11 | jaisalmer
# Processing Record 10 of Set 11 | bitung
# Processing Record 11 of Set 11 | creel
# Processing Record 12 of Set 11 | corinto
# Processing Record 13 of Set 11 | igboho
# Processing Record 14 of Set 11 | naliya
# Processing Record 15 of Set 11 | norrtalje
# Processing Record 16 of Set 11 | laguna
# Processing Record 17 of Set 11 | meulaboh
# Processing Record 18 of Set 11 | basco
# Processing Record 19 of Set 11 | labuhan
# Processing Record 20 of Set 11 | krasnoarmeysk
# Processing Record 21 of Set 11 | chilca
# Processing Record 22 of Set 11 | vagay
# Processing Record 23 of Set 11 | leningradskiy
# Processing Record 24 of Set 11 | barbastro
# Processing Record 25 of Set 11 | tullow
# Processing Record 26 of Set 11 | nome
# Processing Record 27 of Set 11 | arlit
# Processing Record 28 of Set 11 | klyuchi
# Processing Record 29 of Set 11 | road town
# Processing Record 30 of Set 11 | clarence town
# Processing Record 31 of Set 11 | tigil
# Processing Record 32 of Set 11 | quang ngai
# Processing Record 33 of Set 11 | catole do rocha
# Processing Record 34 of Set 11 | akora
# Processing Record 35 of Set 11 | klyuchevskiy
# Processing Record 36 of Set 11 | tual
# Processing Record 37 of Set 11 | limoges
# Processing Record 38 of Set 11 | cairns
# Processing Record 39 of Set 11 | shu
# Processing Record 40 of Set 11 | goma
# Processing Record 41 of Set 11 | turtkul
# City not found. Skipping...
# Processing Record 42 of Set 11 | ulaangom
# Processing Record 43 of Set 11 | ugoofaaru
# Processing Record 44 of Set 11 | dve mogili
# Processing Record 45 of Set 11 | walvis bay
# Processing Record 46 of Set 11 | jacksonville beach
# Processing Record 47 of Set 11 | ayan
# Processing Record 48 of Set 11 | atambua
# Processing Record 49 of Set 11 | upernavik
# Processing Record 50 of Set 11 | strezhevoy
# Processing Record 1 of Set 12 | faya
# Processing Record 2 of Set 12 | garowe
# Processing Record 3 of Set 12 | rusape
# Processing Record 4 of Set 12 | conde
# Processing Record 5 of Set 12 | lahij
# Processing Record 6 of Set 12 | atasu
# Processing Record 7 of Set 12 | hastings
# Processing Record 8 of Set 12 | san rafael
# Processing Record 9 of Set 12 | povenets
# Processing Record 10 of Set 12 | kapit
# Processing Record 11 of Set 12 | chaplynka
# Processing Record 12 of Set 12 | gambela
# Processing Record 13 of Set 12 | jiujiang
# Processing Record 14 of Set 12 | oudtshoorn
# Processing Record 15 of Set 12 | shakiso
# Processing Record 16 of Set 12 | khorinsk
# Processing Record 17 of Set 12 | hokitika
# Processing Record 18 of Set 12 | las palmas
# Processing Record 19 of Set 12 | karratha
# Processing Record 20 of Set 12 | casablanca
# Processing Record 21 of Set 12 | akdepe
# Processing Record 22 of Set 12 | asheville
# Processing Record 23 of Set 12 | stokmarknes
# Processing Record 24 of Set 12 | buchanan
# Processing Record 25 of Set 12 | smederevska palanka
# Processing Record 26 of Set 12 | lavrentiya
# Processing Record 27 of Set 12 | sandnessjoen
# Processing Record 28 of Set 12 | saurimo
# Processing Record 29 of Set 12 | zheleznodorozhnyy
# Processing Record 30 of Set 12 | bonga
# Processing Record 31 of Set 12 | quesnel
# Processing Record 32 of Set 12 | diamantino
# Processing Record 33 of Set 12 | saint-francois
# Processing Record 34 of Set 12 | deputatskiy
# Processing Record 35 of Set 12 | kajaani
# Processing Record 36 of Set 12 | cardinal
# Processing Record 37 of Set 12 | grand gaube
# Processing Record 38 of Set 12 | amalapuram
# Processing Record 39 of Set 12 | nelson bay
# Processing Record 40 of Set 12 | port moresby
# Processing Record 41 of Set 12 | yumen
# Processing Record 42 of Set 12 | angoche
# Processing Record 43 of Set 12 | maraa
# Processing Record 44 of Set 12 | fort thomas
# Processing Record 45 of Set 12 | kamenka
# Processing Record 46 of Set 12 | mayo
# Processing Record 47 of Set 12 | hambantota
# Processing Record 48 of Set 12 | horn lake
# Processing Record 49 of Set 12 | calvinia
# Processing Record 50 of Set 12 | price
# Processing Record 1 of Set 13 | rio gallegos
# Processing Record 2 of Set 13 | krasnyye baki
# Processing Record 3 of Set 13 | champerico
# Processing Record 4 of Set 13 | coro
# Processing Record 5 of Set 13 | gwembe
# Processing Record 6 of Set 13 | chapais
# Processing Record 7 of Set 13 | aguimes
# Processing Record 8 of Set 13 | cockburn town
# Processing Record 9 of Set 13 | davila
# Processing Record 10 of Set 13 | prince george
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 555

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia      AR -54.8000  -68.3000     47.86        46           0
# 1         Hermanus      ZA -34.4187   19.2345     60.80        85           0
# 2          Rikitea      PF -23.1203 -134.9692     73.99        69           0
# 3            Dover      US  39.1582  -75.5244     58.14        84         100
# 4           Touros      BR  -5.1989  -35.4608     80.83        63           5
# 5          Chitral      PK  35.8462   71.7858     64.00        63           3
# 6         Kurumkan      RU  54.3000  110.3000     23.02        74          75
# 7  Barra Do Garcas      BR -15.8900  -52.2567     84.78        48          75
# 8         Kulmbach      DE  50.1000   11.4500     53.83        93         100
# 9     Kamariotissa      GR  40.4833   25.4667     73.76        54           0
#
#    Wind Speed Current Description
# 0        3.44           clear sky
# 1       13.96           clear sky
# 2        5.68           clear sky
# 3       20.71       moderate rain
# 4       16.31           clear sky
# 5        3.44           clear sky
# 6        3.40       broken clouds
# 7       11.50        thunderstorm
# 8        6.40     overcast clouds
# 9       18.54           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
new_df = city_data_df[new_column_order]

# Display sample data
# YOUR CODE HERE
new_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia      AR -54.8000  -68.3000     47.86        46           0
# 1         Hermanus      ZA -34.4187   19.2345     60.80        85           0
# 2          Rikitea      PF -23.1203 -134.9692     73.99        69           0
# 3            Dover      US  39.1582  -75.5244     58.14        84         100
# 4           Touros      BR  -5.1989  -35.4608     80.83        63           5
# 5          Chitral      PK  35.8462   71.7858     64.00        63           3
# 6         Kurumkan      RU  54.3000  110.3000     23.02        74          75
# 7  Barra Do Garcas      BR -15.8900  -52.2567     84.78        48          75
# 8         Kulmbach      DE  50.1000   11.4500     53.83        93         100
# 9     Kamariotissa      GR  40.4833   25.4667     73.76        54           0
#
#    Wind Speed Current Description
# 0        3.44           clear sky
# 1       13.96           clear sky
# 2        5.68           clear sky
# 3       20.71       moderate rain
# 4       16.31           clear sky
# 5        3.44           clear sky
# 6        3.40       broken clouds
# 7       11.50        thunderstorm
# 8        6.40     overcast clouds
# 9       18.54           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
new_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
new_df.to_csv(output_data_file)
